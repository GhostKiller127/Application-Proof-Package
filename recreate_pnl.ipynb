# %%
from proof_package import retrieve_live_performance

# %%
path = '../Evaluation/1 hour data new, d6/live evaluation/Test 2/proof'
path = 'proof'
hours_dt, hourly_cum_realized, equity_hourly = retrieve_live_performance(start_date='2025-09-29 18:00:00', end_date='2025-10-29 16:00:00', start_balance=1000, proof_dir=path, load_only=True)
# Out:
# 3 Positions at 2025-10-29 15:00:00: {'XRPUSDT': {'entryPrice': 3.0453, 'qty': 2.7}, 'OGUSDT': {'entryPrice': 15.3545, 'qty': 0.3}, 'PERPUSDT': {'entryPrice': 0.192, 'qty': 628.0}}
#
# Total closes: 239
# Original Total PnL: 768.065500
# Total funding fees removed: -13.906632
